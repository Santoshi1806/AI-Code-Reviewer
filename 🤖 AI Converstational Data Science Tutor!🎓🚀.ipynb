# %% [markdown]
# <a href="https://colab.research.google.com/github/Santoshi1806/AI-Code-Reviewer/blob/main/%F0%9F%A4%96%20AI%20Converstational%20Data%20Science%20Tutor!%F0%9F%8E%93%F0%9F%9A%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install streamlit -q

# %%
pip install langchain-google-genai

# %%
# !pip install langchain-google-genai

# %%
# !pip install langchain-google-genai
# restart runtime (Runtime > Restart runtime) - This is a comment, not executable code

# %%
pip install langchain_experimental

# %%
import langchain_experimental
print(langchain_experimental.__version__)
# Out:
# 0.3.4

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %%
pip install --upgrade langchain langchain_experimental

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

file_path = "AIzaSyDqMz_ResrlHaSDFL8EQ41GC2fs4tPjsg4.txt"

if os.path.exists(file_path):
    with open(file_path) as f:
        content = f.read()
        print(content)
else:
    print(f"File not found: {file_path}")
# Out:
# File not found: AIzaSyDqMz_ResrlHaSDFL8EQ41GC2fs4tPjsg4.txt

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 35.223.209.116

# %%
! npm install -g localtunnel@2.0.2
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# changed 22 packages in 3s
# ⠴
# ⠴3 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
# ⠙⠹⠸⠼⠴
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.223.209.116:8501
#
# ⠦⠧⠇⠏⠋⠙your url is: https://big-moles-dance.loca.lt
